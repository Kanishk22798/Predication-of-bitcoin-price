# %% [markdown]
# ## Importing the Libraries

# %%
# for basic operations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# for interactive analysis
import ipywidgets
from ipywidgets import interact
from ipywidgets import interact_manual

# for time series analysis
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ## Reading the Data

# %%
# lets import the dataset
data = pd.read_csv('bitcoin.csv')

# lets check the shape of the dataset
data.shape
# Out:
# (1877, 7)

# %%
# lets check the columns in the dataset
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# lets check the head of the dataset
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume
# 0  16389165
# 1  26691849
# 2  29560102
# 3  28736825
# 4  20702624

# %%
# lets check the tail of the dataset
data.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1872  2019-11-02  8291.172852  8397.126953  8282.598633  8349.874023
# 1873  2019-11-03  8349.936523  8399.804688  8186.173828  8270.445313
# 1874  2019-11-04  8270.670898  8541.590820  8259.809570  8458.521484
# 1875  2019-11-05  8458.875000  8540.323242  8359.278320  8436.573242
# 1876  2019-11-06  8435.071289  8512.726563  8406.735352  8456.394531
#
#         Adj Close       Volume
# 1872  8349.874023  19021882025
# 1873  8270.445313  18924326413
# 1874  8458.521484  23517560012
# 1875  8436.573242  23658103729
# 1876  8456.394531  20898606220

# %%
# lets check the summary of the dataset
data.sample(5)
# Out:
#             Date          Open          High           Low         Close  \
# 1860  2019-10-21   7373.166016   7439.778320   7349.857910   7392.276855
# 1201  2017-12-31  10751.666992  11979.170898  10627.895508  11795.034180
# 863   2017-01-27    859.725708    863.632385    858.176575    860.061707
# 1633  2019-03-08   3494.585205   3514.063477   3449.360107   3472.416748
# 1284  2018-03-24   7207.473145   7283.766113   7016.193359   7018.152344
#
#          Adj Close       Volume
# 1860   7392.276855  14229761007
# 1201  11795.034180  10111897617
# 863     860.061707    117443426
# 1633   3472.416748   9469505717
# 1284   7018.152344   4586349335

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# lets check the information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1877 entries, 0 to 1876
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1877 non-null   object
#  1   Open       1877 non-null   float64
#  2   High       1877 non-null   float64
#  3   Low        1877 non-null   float64
#  4   Close      1877 non-null   float64
#  5   Adj Close  1877 non-null   float64
#  6   Volume     1877 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 102.8+ KB

# %%
# lets check the data types of the data
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# lets check the null values if present in the data
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Inferential Statistics

# %%
# lets check basic statistics
x = data.describe()
x.style.bar()
# Out:
# <style  type="text/css" >
# #T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col5,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col1,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col2,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col4{
#             width:  10em;
#              height:  80%;
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.1%, transparent 18.1%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.2%, transparent 18.2%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.7%, transparent 19.7%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col2,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.0%, transparent 6.0%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col2,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.6%, transparent 33.6%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.9%, transparent 32.9%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.8%, transparent 11.8%);
#         }#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col0,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col1,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col2,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col3,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col4,#T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow7_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Open</th>        <th class="col_heading level0 col1" >High</th>        <th class="col_heading level0 col2" >Low</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Adj Close</th>        <th class="col_heading level0 col5" >Volume</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50flevel0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col0" class="data row0 col0" >1877.000000</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col1" class="data row0 col1" >1877.000000</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col2" class="data row0 col2" >1877.000000</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col3" class="data row0 col3" >1877.000000</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col4" class="data row0 col4" >1877.000000</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow0_col5" class="data row0 col5" >1877.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50flevel0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col0" class="data row1 col0" >3154.947491</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col1" class="data row1 col1" >3242.307958</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow1_col2" class="data row1 col2" >3061.373277</td>
#                         <td id="T_1ad38a4e_4146_11ec_a5d3_a0999b07b50frow

# %%
# lets check the correlation
x = data.corr()
x.style.bar(color = ['silver'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col0,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col1,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col2,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col4,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col4,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 100.0%, transparent 100.0%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col1,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col0,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col4,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col4,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col1,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col2,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col1,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.9%, transparent 99.9%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col2,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col4,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col2,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col0,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col1,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col0,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 99.8%, transparent 99.8%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col5,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.3%, transparent 78.3%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col5,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.6%, transparent 78.6%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col5,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.4%, transparent 78.4%);
#         }#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col5,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col5,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col3,#T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 78.5%, transparent 78.5%);
#         }</style><table id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Open</th>        <th class="col_heading level0 col1" >High</th>        <th class="col_heading level0 col2" >Low</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Adj Close</th>        <th class="col_heading level0 col5" >Volume</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row0" class="row_heading level0 row0" >Open</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col1" class="data row0 col1" >0.998790</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col2" class="data row0 col2" >0.998097</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col3" class="data row0 col3" >0.997502</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col4" class="data row0 col4" >0.997502</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow0_col5" class="data row0 col5" >0.783423</td>
#             </tr>
#             <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row1" class="row_heading level0 row1" >High</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col0" class="data row1 col0" >0.998790</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col2" class="data row1 col2" >0.997690</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col3" class="data row1 col3" >0.998988</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col4" class="data row1 col4" >0.998988</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow1_col5" class="data row1 col5" >0.785849</td>
#             </tr>
#             <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row2" class="row_heading level0 row2" >Low</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col0" class="data row2 col0" >0.998097</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col1" class="data row2 col1" >0.997690</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col3" class="data row2 col3" >0.998661</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col4" class="data row2 col4" >0.998661</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow2_col5" class="data row2 col5" >0.783523</td>
#             </tr>
#             <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row3" class="row_heading level0 row3" >Close</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col0" class="data row3 col0" >0.997502</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col1" class="data row3 col1" >0.998988</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col2" class="data row3 col2" >0.998661</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col4" class="data row3 col4" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow3_col5" class="data row3 col5" >0.784861</td>
#             </tr>
#             <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row4" class="row_heading level0 row4" >Adj Close</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col0" class="data row4 col0" >0.997502</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col1" class="data row4 col1" >0.998988</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col2" class="data row4 col2" >0.998661</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col3" class="data row4 col3" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow4_col5" class="data row4 col5" >0.784861</td>
#             </tr>
#             <tr>
#                         <th id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50flevel0_row5" class="row_heading level0 row5" >Volume</th>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col0" class="data row5 col0" >0.783423</td>
#                         <td id="T_1b74b14e_4146_11ec_a5d3_a0999b07b50frow5_col1" c

# %%
# lets check the covariance of the data
x = data.cov()
x.style.bar(color = 'gold', align = 'mid')
# Out:
# <style  type="text/css" >
# #T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col5,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col5,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col5,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col5,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col0,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col1,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col2,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col3,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col4,#T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }</style><table id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Open</th>        <th class="col_heading level0 col1" >High</th>        <th class="col_heading level0 col2" >Low</th>        <th class="col_heading level0 col3" >Close</th>        <th class="col_heading level0 col4" >Adj Close</th>        <th class="col_heading level0 col5" >Volume</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row0" class="row_heading level0 row0" >Open</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col0" class="data row0 col0" >11475741.690472</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col1" class="data row0 col1" >11842264.166148</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col2" class="data row0 col2" >11009896.757403</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col3" class="data row0 col3" >11452487.260161</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col4" class="data row0 col4" >11452487.260161</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow0_col5" class="data row0 col5" >15906146097813.322266</td>
#             </tr>
#             <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row1" class="row_heading level0 row1" >High</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col0" class="data row1 col0" >11842264.166148</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col1" class="data row1 col1" >12250115.141358</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col2" class="data row1 col2" >11370654.257386</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col3" class="data row1 col3" >11850211.705606</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col4" class="data row1 col4" >11850211.705606</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow1_col5" class="data row1 col5" >16484925586170.115234</td>
#             </tr>
#             <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row2" class="row_heading level0 row2" >Low</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col0" class="data row2 col0" >11009896.757403</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col1" class="data row2 col1" >11370654.257386</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col2" class="data row2 col2" >10603270.546356</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col3" class="data row2 col3" >11021329.441767</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col4" class="data row2 col4" >11021329.441767</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow2_col5" class="data row2 col5" >15291482908332.144531</td>
#             </tr>
#             <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row3" class="row_heading level0 row3" >Close</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col0" class="data row3 col0" >11452487.260161</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col1" class="data row3 col1" >11850211.705606</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col2" class="data row3 col2" >11021329.441767</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col3" class="data row3 col3" >11486602.135265</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col4" class="data row3 col4" >11486602.135265</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow3_col5" class="data row3 col5" >15942869198168.972656</td>
#             </tr>
#             <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row4" class="row_heading level0 row4" >Adj Close</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col0" class="data row4 col0" >11452487.260161</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col1" class="data row4 col1" >11850211.705606</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col2" class="data row4 col2" >11021329.441767</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col3" class="data row4 col3" >11486602.135265</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col4" class="data row4 col4" >11486602.135265</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow4_col5" class="data row4 col5" >15942869198168.972656</td>
#             </tr>
#             <tr>
#                         <th id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50flevel0_row5" class="row_heading level0 row5" >Volume</th>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col0" class="data row5 col0" >15906146097813.322266</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col1" class="data row5 col1" >16484925586170.115234</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col2" class="data row5 col2" >15291482908332.144531</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col3" class="data row5 col3" >15942869198168.972656</td>
#                         <td id="T_1c3cdc78_4146_11ec_a5d3_a0999b07b50frow5_col4" class="data row5 col4" >15942869198168.972656</td>
#                         <td

# %%
# lets check the Heatmaps 

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.heatmap(data.corr(),
            cmap = 'Greens',
            annot = True)
plt.title('The Correlation Map for the Data', fontsize = 20)
plt.show()

# %%
# lets check the Heatmaps 

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.heatmap(data.corr(),
            cmap = 'Reds',
            annot = True)
plt.title('The Covariance Map for the Data', fontsize = 20)
plt.show()

# %%
# lets check the pairplot of the data
sns.pairplot(data)
plt.show()

# %%
import dabl
dabl.plot(data, target_col = 'Open')
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# Target looks like regression
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 2 outliers in column Volume.
#   warn("Dropped {} outliers in column {}.".format(
# [array([[<AxesSubplot:title={'center':'F=7.74E+05'}, xlabel='High', ylabel='Open'>,
#          <AxesSubplot:title={'center':'F=4.91E+05'}, xlabel='Low'>,
#          <AxesSubplot:title={'center':'F=3.74E+05'}, xlabel='Adj Close'>,
#          <AxesSubplot:title={'center':'F=3.74E+05'}, xlabel='Close'>,
#          <AxesSubplot:title={'center':'F=2.98E+03'}, xlabel='Volume'>]],
#        dtype=object),
#  None]

# %% [markdown]
# ## Financial Analytics

# %%
# lets convert the date variable into a datetime object
data['Date'] = pd.to_datetime(data['Date'])

# lets check the datatype of the date column now
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['Adj_Close'],
             color = 'gold')
plt.title('Time Series Analysis for Adjusted Closing Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Adjusted Closing Values for Bitcoin Market')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj_Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f59666c1122a> in <module>
#       5
#       6 sns.lineplot(data['Date'],
# ----> 7              data['Adj_Close'],
#       8              color = 'gold')
#       9 plt.title('Time Series Analysis for Adjusted Closing Values of Bitcoin', fontsize = 20)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Adj_Close'

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'], data['Open'])
plt.title('Time Series Analysis for Opening Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Opening Values for Bitcoin Market')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['Close'],
             color = 'black')
plt.title('Time Series Analysis for Closing Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Closing Values for Bitcoin Market')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['High'],
             color = 'red')
plt.title('Time Series Analysis for Highest Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Highest Values for Bitcoin Market')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# lets do some plotting

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

sns.lineplot(data['Date'],
             data['Low'],
             color = 'green')
plt.title('Time Series Analysis for Lowest Values of Bitcoin', fontsize = 20)
plt.xlabel('Date')
plt.grid()
plt.ylabel('Lowest Values for Bitcoin Market')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# lets do some Interactive Analysis

plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

@interact_manual
def check(column = 'Date',
          column2 = ['Open',
                     'Close',
                     'High',
                     'Low',
                     'Adj_Close'],
        colors = ['black','red','green','blue']):
    sns.lineplot(data[column],
                 data[column2],
                 color = colors)
    plt.show()
# Out:
# interactive(children=(Text(value='Date', description='column'), Dropdown(description='column2', options=('Open…

# %% [markdown]
# ## Feature Engineering

# %%
# First, we will create the column ‘daily lag’ which is basically just shifting the ‘Close’ price by one day back. 
# (Note: there are often various metrics we can use but i am choosing ‘Close’ for convenience)

data['Daily Lag'] = data['Close'].shift(1)
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume   Daily Lag
# 0  16389165         NaN
# 1  26691849  355.957367
# 2  29560102  328.539368
# 3  28736825  307.761139
# 4  20702624  318.758972

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Daily returns tells us the returns that we obtain in a day after the stock price closes.

# %%
# lets make a column called Daily Returns

data['Daily Returns'] = (data['Daily Lag']/data['Close']) -1
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume   Daily Lag  Daily Returns
# 0  16389165         NaN            NaN
# 1  26691849  355.957367       0.083454
# 2  29560102  328.539368       0.067514
# 3  28736825  307.761139      -0.034502
# 4  20702624  318.758972       0.026161

# %% [markdown]
# ## Checking Distributions

# %%
# lets check the Distribution of Daily Lag

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Daily Lag'],
             color = 'black')
plt.title('Distribution of Daily Lag', fontsize = 20)
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# lets check the Distribution of Daily Lag

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Daily Returns'],
             color = 'red')
plt.title('Distribution of Daily Returns', fontsize = 20)
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# lets check the Distribution of Volume

plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.distplot(data['Volume'],
             color = 'green')
plt.title('Distribution of Volume', fontsize = 20)
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# lets check the Statistics of Daily Lag and Daily Returns

mean = data['Daily Returns'].mean()
std = data['Daily Returns'].std()
print('Mean for Daily Returns :', mean)
print('Standard Deviation for Daily Returns :', std)
mean_lag = data['Daily Returns'].mean()
std_lag = data['Daily Returns'].std()
print('Mean for Daily Lag :', mean_lag)
print('Standard Deviation for Daily Lag :', std_lag)
# Out:
# Mean for Daily Returns : -0.0009202219778351076
# Standard Deviation for Daily Returns : 0.03941675903822447
# Mean for Daily Lag : -0.0009202219778351076
# Standard Deviation for Daily Lag : 0.03941675903822447

# %%
# Ouch,generally returns are negative but remember that this only considers the returns on a day-to-day basis 
# and so it just tells you that in general the return if you buy and sell on the same day, you will make a loss.

sns.distplot(data['Daily Returns'],
              color = 'black')
plt.axvline(mean,color='red',linestyle='dashed',linewidth=2)

#to plot the std line we plot both the positive and negative values 
plt.axvline(std,color='g',linestyle='dashed',linewidth=2)
plt.axvline(-std,color='g',linestyle='dashed',linewidth=2)
plt.title('Buy and Sell Signals based on the Bitcoin Data', fontsize = 20)
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Kurtosis Values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * ```Kurtosis tells you the ‘fatness’ of the tail and it is important because it tells you how ‘extreme’ can the values get.```

# %%
# lets check the Kurtosis Values

print("Kurtosis Values for Daily Lags : ", data['Daily Lag'].kurtosis())
print("Kurtosis Values for Daily Returns :", data['Daily Returns'].kurtosis())
# Out:
# Kurtosis Values for Daily Lags :  0.2888694715340234
# Kurtosis Values for Daily Returns : 5.770034068011833

# %% [markdown]
# ## Modelling

# %%
#lets split the data into training and testing

from sklearn.model_selection import train_test_split

data_train, data_test = train_test_split(data,
                                         test_size = 0.05, 
                                         random_state = 0)

# printing the sizes of the training and testing datasets
print("Shape of Train Data :", data_train.shape)
print("Shape of Test Data :", data_test.shape)
# Out:
# Shape of Train Data : (1783, 9)
# Shape of Test Data : (94, 9)

# %%
# preparing the Data
training_data = data_train.iloc[:, 1:2]

# lets check the shape of the training data
print("Shape of the Training Data: ", training_data.shape)
# Out:
# Shape of the Training Data:  (1783, 1)

# %%
# lets check the head of the data 
training_data.head()
# Out:
#              Open
# 1025  2210.763184
# 1038  2441.012939
# 434    300.737671
# 596    388.816254
# 1591  3188.943848

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# lets check the head of the training data
training_data
# Out:
# array([[0.12547858],
#        [0.13949922],
#        [0.00917104],
#        ...,
#        [0.21207839],
#        [0.01393536],
#        [0.02492356]])

# %%
# Getting the inputs and outputs

x_train = training_data[0:1782]
y_train = training_data[1:1783]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1782, 1)
# (1782, 1)

# %%
# reshaping

x_train = np.reshape(x_train, (1782, 1, 1))

print(x_train.shape)
# Out:
# (1782, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 56/56 [==============================] - 2s 4ms/step - loss: 0.7466
# Epoch 2/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.5412
# Epoch 3/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3915
# Epoch 4/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2836
# Epoch 5/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2066
# Epoch 6/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1520
# Epoch 7/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1142
# Epoch 8/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0883
# Epoch 9/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0711
# Epoch 10/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0599
# Epoch 11/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0527
# Epoch 12/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0483
# Epoch 13/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0457
# Epoch 14/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0442
# Epoch 15/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0434
# Epoch 16/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0429
# Epoch 17/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0427
# Epoch 18/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0426
# Epoch 19/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 20/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 21/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 22/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 23/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 24/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 25/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 26/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 27/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 28/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 29/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 30/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 31/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 32/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 33/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 34/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 35/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 36/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 37/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 38/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 39/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 40/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 41/200
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0425
# Epoch 42/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 43/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 44/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 45/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 46/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 47/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 48/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 49/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 50/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 51/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 52/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 53/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 54/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 55/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 56/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 57/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 58/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 59/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 60/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 61/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 62/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 63/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 64/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 65/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 66/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 67/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 68/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 69/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 70/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 71/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 72/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 73/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 74/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 75/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 76/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 77/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 78/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 79/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 80/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 81/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 82/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 83/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 84/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 85/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 86/200
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 87/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 88/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 89/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 90/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 91/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 92/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 93/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 94/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 95/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 96/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 97/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 98/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 99/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 100/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 101/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 102/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 103/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 104/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 105/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 106/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 107/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 108/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 109/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 110/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 111/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 112/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 113/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 114/200
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0425
# Epoch 115/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 116/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 117/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 118/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 119/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 120/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 121/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 122/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 123/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 124/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 125/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 126/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 127/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 128/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 129/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 130/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 131/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 132/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 133/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 134/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 135/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 136/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 137/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 138/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 139/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 140/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 141/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 142/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 143/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 144/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 145/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 146/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 147/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 148/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 149/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 150/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 151/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 152/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 153/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 154/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 155/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 156/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 157/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 158/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 159/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 160/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 161/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 162/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 163/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 164/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 165/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 166/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 167/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 168/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 169/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 170/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 171/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 172/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 173/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 174/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 175/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 176/200
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 177/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 178/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 179/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 180/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 181/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 182/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 183/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 184/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 185/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 186/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 187/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 188/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 189/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 190/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 191/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 192/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 193/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 194/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 195/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 196/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 197/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 198/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 199/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 200/200
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0425

# %%
# getting the real stock of 2017 i.e., importing the test dataset

real_bitcoin_price = data_test.iloc[:,1:2]
real_bitcoin_price.head()
# Out:
#              Open
# 994   2546.259521
# 124    182.949203
# 217    219.430008
# 1423  5702.377441
# 1467  5711.379395

# %%
# getting the predicted stock price of 2017

inputs = real_bitcoin_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (94, 1, 1))


predicted_bitcoin_price = model.predict(inputs)
predicted_bitcoin_price = mm.inverse_transform(predicted_bitcoin_price)

# %%
# lets print the predicted bitcoin price
print(predicted_bitcoin_price.shape)
print(real_bitcoin_price.shape)
# Out:
# (94, 1)
# (94, 1)

# %% [markdown]
# ## Time Series Analysis with ARIMA

# %%
# lets import the data 

test = pd.read_csv('Test.csv', index_col = 'Date')
train = pd.read_csv('Training.csv', index_col = 'Date')

# lets check the shape of the dataset
print("Shape of Test Dataset :", test.shape)
print("Shape of Train Dataset :", train.shape)
# Out:
# Shape of Test Dataset : (7, 6)
# Shape of Train Dataset : (1556, 6)

# %%
# lets check the head of the training dataset

train = train.sort_index()
train.index = pd.to_datetime(train.index)
train.head()
# Out:
#                Open     High      Low    Close       Volume      Market Cap
# Date
# 2014-04-01   457.00   495.34   457.00   478.38   35,685,800   5,752,280,000
# 2015-04-01   244.22   247.54   241.16   247.27   22,877,200   3,420,100,000
# 2016-04-01   416.76   418.17   415.83   417.96   51,235,700   6,409,540,000
# 2017-04-01  1071.71  1091.72  1061.09  1080.50  289,634,000  17,413,000,000
# 2014-04-02   479.14   495.05   431.27   437.14   49,647,600   6,032,970,000

# %%
# lets check the head of the testing dataset

test = test.sort_index()
test.index = pd.to_datetime(test.index)
test.head()
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# Date
# 2017-08-01  2871.30  2921.35  2685.61  2718.26  1,324,670,000  47,321,800,000
# 2017-08-02  2727.13  2762.53  2668.59  2710.67  1,094,950,000  44,950,800,000
# 2017-08-03  2709.56  2813.31  2685.14  2804.73    804,797,000  44,666,400,000
# 2017-08-04  2806.93  2899.33  2743.72  2895.89  1,002,120,000  46,276,200,000
# 2017-08-05  2897.63  3290.01  2874.83  3252.91  1,945,700,000  47,778,200,000

# %%
# preparing the data

train = train['Close']
train.head()
# Out:
# Date
# 2014-04-01     478.38
# 2015-04-01     247.27
# 2016-04-01     417.96
# 2017-04-01    1080.50
# 2014-04-02     437.14
# Name: Close, dtype: float64

# %%
# checking the time series on daily basis

by_day = train.groupby(train.index.dayofyear).mean()
by_day.plot(color = 'red')
plt.title('Analyzing Bitcoin Prices on Daily Basis', fontsize = 20)
plt.ylabel('Prices on Daily Basis')
plt.xlabel('Days')
plt.show()

# %%
# checking the time series on day basis

by_weekday = train.groupby(train.index.dayofweek).sum()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(color = 'green')
plt.title('Analyzing Bitcoin Prices on Day Basis', fontsize = 20)
plt.ylabel('Prices on Day Basis')
plt.xlabel('Days')
plt.show()

# %%
# analyzing data weekly

plt.rcParams['figure.figsize'] = (15, 6)
weekly = train.resample('W').sum()
weekly.plot()
plt.ylabel('Weekly bitcoin price')
plt.title('Analyzing Bitcoin Prices on Weekly Basis', fontsize = 20)
plt.show()

# %%
# comparing the prices for weekends and weekdays

weekend = np.where(train.index.weekday < 5, 'Weekday', 'Weekend')
by_time = train.groupby([weekend, train.index.year]).mean()
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.loc['Weekday'].plot(ax=ax[0],
                            title='Weekdays',
                            color = 'pink')
by_time.loc['Weekend'].plot(ax=ax[1],
                            title='Weekends',
                            color = 'yellow')
plt.show()

# %%
# checking the time series on monthly basis

by_month = train.groupby(train.index.month).mean()
by_month.plot(color = 'grey')
plt.title('Analyzing Bitcoin Prices on Monthly Basis', fontsize = 20)
plt.ylabel('Prices on Monthly Basis')
plt.xlabel('Year')
plt.show()

# %%
# checking the prices on quarterly basis

by_quarter = train.groupby(train.index.quarter).mean()
by_quarter.plot(color = 'gold')
plt.title('Analyzing Bitcoin Prices on Quarterly Basis', fontsize = 20)
plt.ylabel('Prices on Quarterly Basis')
plt.xlabel('Year')
plt.show()

# %%
by_quarter = train.groupby(train.index.quarter)
by_quarter.plot()
plt.title('Comparing the Prices in Different Quarters', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking the prices yearly

by_year = train.groupby(train.index.year).mean()
by_year.plot(color = 'black')
plt.title('Analyzing Bitcoin Prices on Yearly Basis', fontsize = 20)
plt.ylabel('Prices on Yearly Basis')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ## Statistical Transformations

# %%
# lets change the name of the data

plt.rcParams['figure.figsize'] = (15, 9)
ts = train
ts.plot()
plt.title('Statistical Transforming', fontsize = 20)
plt.show()

# %%
ts = ts.sort_index()
ts
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
plt.style.use('fivethirtyeight')

def test_for_stationary(input_data):
    r_mean = input_data.rolling(window = 7,center=False).mean()
    r_std = input_data.rolling(window = 7,center=False).std()
    
    # plotting the data
    given = plt.plot(input_data, color = 'blue', label = 'given_series')
    rolling_mean = plt.plot(r_mean, color = 'red', label = 'rolling_mean')
    rolling_std = plt.plot(r_std, color ='green', label = 'rolling_std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
     #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(input_data)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

test_for_stationary(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                    2.535589
# p-value                           0.999060
# #Lags Used                       24.000000
# Number of Observations Used    1531.000000
# Critical Value (1%)              -3.434628
# Critical Value (5%)              -2.863430
# Critical Value (10%)             -2.567776
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Transformation to Eliminate the Trend

# %%
ts_logtransformed = np.log(ts)
plt.plot(ts_logtransformed)
plt.title('Log Transformed Data', fontsize = 20)
plt.show()

# %% [markdown]
# ## Smoothing by Rolling Average

# %%
Rolling_average = ts_logtransformed.rolling(window = 7, center= False).mean()
plt.plot(ts_logtransformed, label = 'Log Transformed')
plt.plot(Rolling_average, color = 'red', label = 'Rolling Average')
plt.legend(loc = 'best')
plt.title('Log Transfomed Data with Rolling Average', fontsize = 20)
plt.show()

# %%
# The red line shows the rolling mean.
# Note that since we are taking average of last 7 values, rolling mean is not defined for first 7 values. 
# This can be observed as:
Rolling_average.head(10)
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29         NaN
# 2013-04-30         NaN
# 2013-05-01         NaN
# 2013-05-02         NaN
# 2013-05-03         NaN
# 2013-05-04    4.790121
# 2013-05-05    4.769180
# 2013-05-06    4.733125
# 2013-05-07    4.701632
# Name: Close, dtype: float64

# %%
#Lets subtract this Rolling average this from the original log transfomred series.

log_Rolling_difference = ts_logtransformed - Rolling_average
log_Rolling_difference.head(10)
log_Rolling_difference.tail(10)
# Out:
# Date
# 2017-07-22    0.151593
# 2017-07-23    0.073239
# 2017-07-24    0.051861
# 2017-07-25   -0.030130
# 2017-07-26   -0.063797
# 2017-07-27   -0.001463
# 2017-07-28    0.041254
# 2017-07-29    0.015741
# 2017-07-30    0.025554
# 2017-07-31    0.061402
# Name: Close, dtype: float64

# %%
#Replace NAN with 0 in the above dataframe to avoid any errors in the future.

log_Rolling_difference.dropna(inplace=True)
plt.plot(log_Rolling_difference)
plt.title('Log Rolling Difference', fontsize = 20)
plt.show()

# %%
# checkin the rolling mean and rolling standard deviaton in the log rolling difference

test_for_stationary(log_Rolling_difference)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.191326e+00
# p-value                        2.499260e-10
# #Lags Used                     2.200000e+01
# Number of Observations Used    1.527000e+03
# Critical Value (1%)           -3.434640e+00
# Critical Value (5%)           -2.863435e+00
# Critical Value (10%)          -2.567779e+00
# dtype: float64

# %%
#Use exponential_weighted_moving_average instead of moving average to improve the solution

expwighted_avg = ts_logtransformed.ewm(halflife=7,min_periods=0,adjust=True,ignore_na=False).mean()
plt.plot(ts_logtransformed, label = 'Log transfomed')
plt.plot(expwighted_avg, color='red', label = 'exponential weighted average')
plt.legend(loc = 'best')
plt.title('Exponential Weighted Average', fontsize = 20)
plt.show()

# %%
expwighted_avg.head(10)
# Out:
# Date
# 2013-04-28    4.899406
# 2013-04-29    4.938315
# 2013-04-30    4.936906
# 2013-05-01    4.886513
# 2013-05-02    4.830850
# 2013-05-03    4.778564
# 2013-05-04    4.768079
# 2013-05-05    4.765448
# 2013-05-06    4.758372
# 2013-05-07    4.751720
# Name: Close, dtype: float64

# %%
log_expmovwt_diff = ts_logtransformed - expwighted_avg

test_for_stationary(log_expmovwt_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -5.442038
# p-value                           0.000003
# #Lags Used                       23.000000
# Number of Observations Used    1532.000000
# Critical Value (1%)              -3.434626
# Critical Value (5%)              -2.863428
# Critical Value (10%)             -2.567775
# dtype: float64

# %% [raw]
# Now the current time series is stationary,the TS (test_statistic) value is less than 1% critcal value. Since weights are assigned to values from the starting index. Therefore the test works
#
# Few other methods to eliminate Trend and seasonality. Here i am implementing Differencing and Decompostion

# %%
ts_logtransformed.plot()
plt.title('Log Transformed Plot', fontsize = 20)
plt.show()

# %% [markdown]
# ## Seasonality Adjustment by Differencing
#
# * Seasonal components in a Time series can be elimnated by using differencing. If there is a seasonal component at level of one month, then it can be removed on an observation today by substracting the value from last month (Ex: Value(Oct 1)-Value(sep 1), value (oct 2 - Value(Sep 2),.....) We can substract last months data to the presents (giving a gap of 30 days) and first months data would not be available for modeling

# %%
ts_diff_logtrans = ts_logtransformed -ts_logtransformed.shift(7)
plt.plot(ts_diff_logtrans)
ts_diff_logtrans.head(10)
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29         NaN
# 2013-04-30         NaN
# 2013-05-01         NaN
# 2013-05-02         NaN
# 2013-05-03         NaN
# 2013-05-04         NaN
# 2013-05-05   -0.146592
# 2013-05-06   -0.252382
# 2013-05-07   -0.220449
# Name: Close, dtype: float64

# %%
ts_diff_logtrans.dropna(inplace=True)
test_for_stationary(ts_diff_logtrans)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.523574e+00
# p-value                        1.027774e-08
# #Lags Used                     2.300000e+01
# Number of Observations Used    1.525000e+03
# Critical Value (1%)           -3.434645e+00
# Critical Value (5%)           -2.863437e+00
# Critical Value (10%)          -2.567780e+00
# dtype: float64

# %% [markdown]
# ## Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.style.use('seaborn-deep')

decomposition = seasonal_decompose(ts_logtransformed)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_logtransformed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
decomposed_TS = residual
decomposed_TS.dropna(inplace=True)
test_for_stationary(decomposed_TS)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.256779e+01
# p-value                        2.035387e-23
# #Lags Used                     2.300000e+01
# Number of Observations Used    1.526000e+03
# Critical Value (1%)           -3.434642e+00
# Critical Value (5%)           -2.863436e+00
# Critical Value (10%)          -2.567779e+00
# dtype: float64

# %% [markdown]
# ## Forecasting

# %%
#ACF and PACF plots:
lag_acf = acf(ts_diff_logtrans, nlags=30)
lag_pacf = pacf(ts_diff_logtrans, nlags=50, method='ols')
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:662: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_diff_logtrans)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_diff_logtrans)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.show()

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_diff_logtrans)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_diff_logtrans)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
pyplot.figure()
pyplot.subplot(211)
plot_acf(ts_diff_logtrans, ax=pyplot.gca(),lags=40)
pyplot.subplot(212)
plot_pacf(ts_diff_logtrans, ax=pyplot.gca(), lags=50)
pyplot.show()

# %% [raw]
# Below are some observations from the plots.
#
# In this plot, the two dotted lines on either sides of 0 are the confidence interevals. These can be used to determine the ‘p’ and ‘q’ values as: the Lag values are identified from PACF and ACF plots for Autoregression(AR) and Moving Average(MA) parameters, p and q respectively p – The lag value where the PACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case p=2, The PACF shows a significant lag on day 2
#
# q – The lag value where the ACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case q=18, since the ACF shows a significant lag for 18th day.
#
# The PACF perhaps has some significant lag at 7th, 8th, 12th, 15th day and so on, which also suggests that there is still some seasonality present in the differenced data. We will try different orders of ARIMA models to identify the best order by deriving the residual sum of squares(RSS) for each model. Lower RSS are considered to be the best ones

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### AR Model

# %%
# preparing ar model

model = ARIMA(ts_logtransformed, order=(8, 1, 0))  
results_AR = model.fit(disp=-1)  

plt.plot(ts_diff_logtrans)
plt.plot(results_AR.fittedvalues, color='red', label = 'order 8')

RSS = results_AR.fittedvalues-ts_diff_logtrans
RSS.dropna(inplace=True)

plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc = 'best')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
# another AR Model

model = ARIMA(ts_logtransformed, order=(2, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(ts_diff_logtrans)
plt.plot(results_AR.fittedvalues, color='red', label = 'order 2')
RSS = results_AR.fittedvalues-ts_diff_logtrans
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc ='best')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
print(results_AR.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 1555
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                2704.690
# Method:                       css-mle   S.D. of innovations              0.042
# Date:                Tue, 09 Nov 2021   AIC                          -5401.380
# Time:                        15:54:49   BIC                          -5379.984
# Sample:                    04-29-2013   HQIC                         -5393.424
#                          - 07-31-2017
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0020      0.001      1.908      0.056   -5.37e-05       0.004
# ar.L1.D.Close    -0.0011      0.025     -0.044      0.965      -0.051       0.049
# ar.L2.D.Close    -0.0435      0.025     -1.715      0.086      -0.093       0.006
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.0127           -4.7948j            4.7948           -0.2504
# AR.2           -0.0127           +4.7948j            4.7948            0.2504
# -----------------------------------------------------------------------------

# %% [markdown]
# ### MA Model

# %%
# preparing an MA Model

model = ARIMA(ts_logtransformed, order=(0, 1,18)) 
results_MA = model.fit(disp=-1)  

plt.plot(ts_diff_logtrans)
plt.plot(results_MA.fittedvalues, color='red')

RSS = results_MA.fittedvalues-ts_diff_logtrans
RSS.dropna(inplace=True)

plt.title('RSS: %.4f'% sum(RSS**2))
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
#model summary
print(results_MA.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 1555
# Model:                ARIMA(0, 1, 18)   Log Likelihood                2727.323
# Method:                       css-mle   S.D. of innovations              0.042
# Date:                Tue, 09 Nov 2021   AIC                          -5414.646
# Time:                        15:55:49   BIC                          -5307.661
# Sample:                    04-29-2013   HQIC                         -5374.862
#                          - 07-31-2017
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0019      0.001      1.374      0.169      -0.001       0.005
# ma.L1.D.Close     -0.0100      0.026     -0.390      0.697      -0.060       0.040
# ma.L2.D.Close     -0.0373      0.025     -1.469      0.142      -0.087       0.012
# ma.L3.D.Close     -0.0222      0.026     -0.871      0.384      -0.072       0.028
# ma.L4.D.Close      0.0759      0.026      2.962      0.003       0.026       0.126
# ma.L5.D.Close      0.0271      0.026      1.039      0.299      -0.024       0.078
# ma.L6.D.Close      0.0821      0.026      3.142      0.002       0.031       0.133
# ma.L7.D.Close     -0.0306      0.027     -1.151      0.250      -0.083       0.022
# ma.L8.D.Close     -0.0069      0.026     -0.262      0.793      -0.058       0.045
# ma.L9.D.Close     -0.0087      0.027     -0.326      0.745      -0.061       0.043
# ma.L10.D.Close     0.0441      0.026      1.685      0.092      -0.007       0.095
# ma.L11.D.Close     0.0772      0.025      3.047      0.002       0.028       0.127
# ma.L12.D.Close    -0.0106      0.028     -0.381      0.703      -0.065       0.044
# ma.L13.D.Close     0.0372      0.025      1.480      0.139      -0.012       0.086
# ma.L14.D.Close     0.0325      0.028      1.147      0.251      -0.023       0.088
# ma.L15.D.Close     0.0299      0.029      1.030      0.303      -0.027       0.087
# ma.L16.D.Close     0.0025      0.027      0.091      0.927      -0.051       0.056
# ma.L17.D.Close     0.0832      0.027      3.048      0.002       0.030       0.137
# ma.L18.D.Close    -0.0335      0.028     -1.211      0.226      -0.088       0.021
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# MA.1            -1.1293           -0.0000j            1.1293           -0.5000
# MA.2            -1.0360           -0.4363j            1.1241           -0.4366
# MA.3            -1.0360           +0.4363j            1.1241            0.4366
# MA.4            -0.8723           -0.7427j            1.1457           -0.3877
# MA.5            -0.8723           +0.7427j            1.1457            0.3877
# MA.6            -0.5234           -0.9971j            1.1261           -0.3269
# MA.7            -0.5234           +0.9971j            1.1261            0.3269
# MA.8            -0.1031           -1.1561j            1.1607           -0.2642
# MA.9            -0.1031           +1.1561j            1.1607            0.2642
# MA.10            0.2555           -1.1746j            1.2020           -0.2159
# MA.11            0.2555           +1.1746j            1.2020            0.2159
# MA.12            0.6969           -0.9478j            1.1764           -0.1491
# MA.13            0.6969           +0.9478j            1.1764            0.1491
# MA.14            1.0915           -0.2689j            1.1242           -0.0384
# MA.15            1.0915           +0.2689j            1.1242            0.0384
# MA.16            0.9436           -0.6872j            1.1673           -0.1002
# MA.17            0.9436           +0.6872j            1.1673            0.1002
# MA.18            2.7060           -0.0000j            2.7060           -0.0000
# ------------------------------------------------------------------------------

# %% [markdown]
# ### ARIMA Combined Model

# %%
# preparing a combined Model

model = ARIMA(ts_logtransformed, order=(8, 1, 18))  
results_ARIMA = model.fit(trend= 'nc', disp=-1) 

plt.plot(ts_diff_logtrans)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =8, q =18')

RSS =results_ARIMA.fittedvalues-ts_diff_logtrans
RSS.dropna(inplace=True)

plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
plt.show()
# Out:
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/kanishkgupta/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %% [raw]
# model = ARIMA(ts_logtransformed, order=(20, 1, 18)) results_ARIMA = model.fit(disp=-1)
# plt.plot(ts_diff_logtrans) plt.plot(results_ARIMA.fittedvalues, color='red', label = 'order 15') RSS = results_ARIMA.fittedvalues-ts_diff_logtrans RSS.dropna(inplace=True) plt.title('RSS: %.4f'% sum(RSS**2)) plt.legend(loc = 'best')

# %% [raw]
# model = ARIMA(ts_logtransformed, order=(20, 1, 18)) results_ARIMA = model.fit(disp=-1)
# plt.plot(ts_diff_logtrans) plt.plot(results_ARIMA.fittedvalues, color='red', label = 'order 15') RSS = results_ARIMA.fittedvalues-ts_diff_logtrans RSS.dropna(inplace=True) plt.title('RSS: %.4f'% sum(RSS**2)) plt.legend(loc = 'best')
#
# Searching ARIMA parameters.
# The above plots and models derive varying residual RSS. evaluating all these models might be difficult. SO we do a grid search on all possible ARIMA parameters. We look for different p,d,q combinations, and find the best combination. p = 7 ,10,13,16,19 d = 0 to 2 taking 10 runs of the model and this will take some time to run
#
# The following markdown is a python code that helps to evaluate different model performances to evaluate best ARIMA hyperparameters
#
#
# import warnings def evaluate_arima_model(data_set, arima_order): model = ARIMA(data_set, order=arima_order) results_ARIMA = model.fit(disp=-1) RSS_diff = results_ARIMA.fittedvalues-ts_diff_logtrans RSS = RSS_diff**2 return RSS def evaluate_models(dataset, p_values, d_values): best_score, best_cfg = float("inf"), None for p in p_values: for d in d_values: order = (p,d,18) try: rss = evaluate_arima_model(dataset, order) if rss < best_score: best_score, best_cfg = rss, order print('ARIMA%s RSS=%.3f' % (order,rss)) except: continue print('Best ARIMA%s RSS=%.3f' % (best_cfg, best_score)) p_values = range(8,20,3) d_values = range(0,3) warnings.filterwarnings('ignore') evaluate_models(ts_logtransformed,p_values,d_values)
#
# We can derive the Summary of the ARIMA model as follows explaining the results

# %%
#model summary
print(results_ARIMA.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 1555
# Model:                ARIMA(8, 1, 18)   Log Likelihood                2744.939
# Method:                       css-mle   S.D. of innovations              0.041
# Date:                Tue, 09 Nov 2021   AIC                          -5435.878
# Time:                        16:07:40   BIC                          -5291.449
# Sample:                    04-29-2013   HQIC                         -5382.170
#                          - 07-31-2017
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ar.L1.D.Close     -1.2597      0.318     -3.965      0.000      -1.882      -0.637
# ar.L2.D.Close     -0.7752      0.507     -1.529      0.126      -1.769       0.219
# ar.L3.D.Close     -0.7146      0.417     -1.713      0.087      -1.532       0.103
# ar.L4.D.Close     -0.6843      0.337     -2.028      0.043      -1.346      -0.023
# ar.L5.D.Close     -0.1629      0.305     -0.533      0.594      -0.762       0.436
# ar.L6.D.Close      0.4317      0.253      1.708      0.088      -0.064       0.927
# ar.L7.D.Close      0.2094      0.320      0.654      0.513      -0.418       0.837
# ar.L8.D.Close     -0.2494      0.259     -0.965      0.335      -0.756       0.257
# ma.L1.D.Close      1.2592      0.316      3.984      0.000       0.640       1.879
# ma.L2.D.Close      0.7353      0.506      1.454      0.146      -0.256       1.727
# ma.L3.D.Close      0.6627      0.407      1.629      0.103      -0.135       1.460
# ma.L4.D.Close      0.7152      0.319      2.242      0.025       0.090       1.340
# ma.L5.D.Close      0.2375      0.296      0.804      0.422      -0.342       0.817
# ma.L6.D.Close     -0.3088      0.247     -1.249      0.212      -0.793       0.176
# ma.L7.D.Close     -0.0795      0.284     -0.279      0.780      -0.637       0.478
# ma.L8.D.Close      0.3614      0.221      1.635      0.102      -0.072       0.795
# ma.L9.D.Close      0.0650      0.071      0.916      0.360      -0.074       0.204
# ma.L10.D.Close     0.0387      0.065      0.600      0.549      -0.088       0.165
# ma.L11.D.Close     0.0873      0.058      1.507      0.132      -0.026       0.201
# ma.L12.D.Close     0.0926      0.060      1.537      0.124      -0.025       0.211
# ma.L13.D.Close     0.1119      0.065      1.710      0.087      -0.016       0.240
# ma.L14.D.Close     0.1712      0.065      2.639      0.008       0.044       0.298
# ma.L15.D.Close     0.1523      0.064      2.385      0.017       0.027       0.277
# ma.L16.D.Close     0.1168      0.063      1.858      0.063      -0.006       0.240
# ma.L17.D.Close     0.1196      0.056      2.150      0.032       0.011       0.229
# ma.L18.D.Close     0.1145      0.032      3.583      0.000       0.052       0.177
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -0.9952           -0.2766j            1.0329           -0.4569
# AR.2            -0.9952           +0.2766j            1.0329            0.4569
# AR.3            -0.6197           -0.8507j            1.0525           -0.3502
# AR.4            -0.6197           +0.8507j            1.0525            0.3502
# AR.5             0.3667           -0.9465j            1.0150           -0.1912
# AR.6             0.3667           +0.9465j            1.0150            0.1912
# AR.7             1.6681           -0.7150j            1.8148           -0.0644
# AR.8             1.6681           +0.7150j            1.8148            0.0644
# MA.1            -1.0221           -0.2417j            1.0503           -0.4630
# MA.2            -1.0221           +0.2417j            1.0503            0.4630
# MA.3            -1.0380           -0.4148j            1.1178           -0.4395
# MA.4            -1.0380           +0.4148j            1.1178            0.4395
# MA.5            -0.7437           -0.8588j            1.1360           -0.3636
# MA.6            -0.7437           +0.8588j            1.1360            0.3636
# MA.7            -0.5875           -0.9069j            1.0805           -0.3415
# MA.8            -0.5875           +0.9069j            1.0805            0.3415
# MA.9             1.0931           -0.2783j            1.1279           -0.0397
# MA.10            1.0931           +0.2783j            1.1279            0.0397
# MA.11            0.9252           -0.7198j            1.1722           -0.1052
# MA.12            0.9252           +0.7198j            1.1722            0.1052
# MA.13           -0.0746           -1.2397j            1.2420           -0.2596
# MA.14           -0.0746           +1.2397j            1.2420            0.2596
# MA.15            0.3559           -0.9664j            1.0298           -0.1938
# MA.16            0.3559           +0.9664j            1.0298            0.1938
# MA.17            0.5696           -1.0705j            1.2126           -0.1722
# MA.18            0.5696           +1.0705j            1.2126            0.1722
# ------------------------------------------------------------------------------

# %%
plt.plot(ts_logtransformed, label = 'log_tranfromed_data')
plt.plot(results_ARIMA.resid, color ='green',label= 'Residuals')
plt.title('ARIMA Model Residual plot')
plt.legend(loc = 'best')
plt.show()

# %%
results_ARIMA.resid.plot(kind='kde')
plt.title('Density plot of the residual error values')
print(results_ARIMA.resid.describe())
# Out:
# count    1555.000000
# mean        0.001500
# std         0.041420
# min        -0.246335
# 25%        -0.012671
# 50%         0.001621
# 75%         0.018297
# max         0.320604
# dtype: float64

# %%
test = pd.read_csv("Test.csv",index_col= 'Date')
test.index = pd.to_datetime(test.index)
test = test['Close']
test = test.sort_index()
test
# Out:
# Date
# 2017-08-01    2718.26
# 2017-08-02    2710.67
# 2017-08-03    2804.73
# 2017-08-04    2895.89
# 2017-08-05    3252.91
# 2017-08-06    3213.94
# 2017-08-07    3378.94
# Name: Close, dtype: float64

# %% [markdown]
# ### Using Combined ARIMA to predict and forecast

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# Date
# 2013-04-29    0.000000
# 2013-04-30   -0.000021
# 2013-05-01   -0.002728
# 2013-05-02    0.000189
# 2013-05-03    0.011427
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
# Out:
# Date
# 2013-04-29    0.000000
# 2013-04-30   -0.000021
# 2013-05-01   -0.002749
# 2013-05-02   -0.002560
# 2013-05-03    0.008866
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(ts_logtransformed.iloc[0], index=ts_logtransformed.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Date
# 2013-04-28    4.899406
# 2013-04-29    4.899406
# 2013-04-30    4.899385
# 2013-05-01    4.896657
# 2013-05-02    4.896846
# dtype: float64

# %% [markdown]
# ## Forecast

# %%
from sklearn.metrics import mean_squared_error

dates = [pd.Timestamp('2017-08-01'), pd.Timestamp('2017-08-02'), 
         pd.Timestamp('2017-08-03'),pd.Timestamp('2017-08-04'), 
         pd.Timestamp('2017-08-05'), pd.Timestamp('2017-08-06'), 
         pd.Timestamp('2017-08-07')]

forecast = pd.Series(results_ARIMA.forecast(steps=7)[0],dates)
forecast = np.exp(forecast)
print(forecast)
error = mean_squared_error(test, forecast)
print('Test MSE: %.3f' % error)
# Out:
# 2017-08-01    2878.427402
# 2017-08-02    2933.838503
# 2017-08-03    3007.149018
# 2017-08-04    3025.493955
# 2017-08-05    2979.597490
# 2017-08-06    3019.348411
# 2017-08-07    2951.499072
# dtype: float64
# Test MSE: 61214.255

# %%
plt.plot(forecast, color ='green', label ='Predicted rates')
plt.plot(test, color = 'red', label = 'Observed from test data')
plt.title('RMSE: %.4f'% np.sqrt(sum((forecast-test)**2)/len(data)))
plt.legend(loc = 'best')
